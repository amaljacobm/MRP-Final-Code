# %% [markdown]
# # Import pandas and read files

# %%
import pandas as pd
df = pd.read_excel('2012-2014.xlsx', 'Sheet1')
df
# Out:
#         HS6-SH6                                 DESCRIPTION_ENG  \
# 0         10121                Horses, live, pure-bred breeding
# 1         10121                Horses, live, pure-bred breeding
# 2         10121                Horses, live, pure-bred breeding
# 3         10121                Horses, live, pure-bred breeding
# 4         10121                Horses, live, pure-bred breeding
# ...         ...                                             ...
# 672773   970600  Antiques of an age exceeding one hundred years
# 672774   970600  Antiques of an age exceeding one hundred years
# 672775   970600  Antiques of an age exceeding one hundred years
# 672776   970600  Antiques of an age exceeding one hundred years
# 672777   970600  Antiques of an age exceeding one hundred years
#
#                              COMPANY-ENTREPRISE  \
# 0                    HATFIELD FARM INCORPORATED
# 1                         9125-3575 QUEBEC INC.
# 2                          9125-3575 QUEBEC INC
# ...

# %%
path = ('2015-2016.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['Sheet1']

# %%
df1 = xl.parse('Sheet1')
df1
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        482190             Paper labels of all kinds, not printed
# 1         70190                    Potatoes, fresh or chilled, nes
# 2         70200                         Tomatoes, fresh or chilled
# 3         70200                         Tomatoes, fresh or chilled
# 4         70200                         Tomatoes, fresh or chilled
# ...         ...                                                ...
# 434732   940360                             Furniture, wooden, nes
# 434733   940360                             Furniture, wooden, nes
# 434734   630293       Toilet and kitchen linen, of man-made fibres
# 434735   630391  Curtains,incl drapes,int blinds & curtain/bed ...
# 434736   630391  Curtains,incl drapes,int blinds & curtain/bed ...
#
#                                        COMPANY-ENTREPRISE        COUNTRY  \
# 0                            PROVINCIAL FRUIT CO. LIMITED  United States
# ...

# %%
df2 = pd.read_excel('2017-2018.xlsx', 'Sheet1')
df2
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0         80711                                 Watermelons, fresh
# 1         80711                                 Watermelons, fresh
# 2         80711                                 Watermelons, fresh
# 3         80711                                 Watermelons, fresh
# 4         80719                                 Melons, nes, fresh
# ...         ...                                                ...
# 648697   901910  Mechano-therapy appl; massage app; psychologic...
# 648698   901790  Parts and accessories for use with the apparat...
# 648699   903190  Pts & acces,f measuring/checking inst,app & ma...
# 648700   903190  Pts & acces,f measuring/checking inst,app & ma...
# 648701   903190  Pts & acces,f measuring/checking inst,app & ma...
#
#                            COMPANY-ENTREPRISE        COUNTRY PROVINCE_ENG  \
# 0       CANADIAN FRUIT & PRODUCE COMPANY INC.  United States      Ontario
# ...

# %%
df3 = pd.read_excel('2019-2020.xlsx', 'Sheet1')
df3
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        392410             Tableware and kitchenware, of plastics
# 1        732393  Table, kitchen or other household art & parts ...
# 2        821520  Tableware sets not containing articles plated ...
# 3        830241  Mountings, fittings and similar articles of ba...
# 4        890590  Floating docks and vessels which perform speci...
# ...         ...                                                ...
# 759802   961380                                      Lighters, nes
# 759803   961511  Combs, hair-slides and the like of hard rubber...
# 759804   961519  Combs, hair-slides and the like, other than ha...
# 759805   961590  Hairpins, curling pins, hair-curlers and the l...
# 759806   961700  Vacuum flasks/vacuum vessels complete with cas...
#
#                COMPANY-ENTREPRISE        COUNTRY PROVINCE_ENG      CITY-VILLE  \
# 0               ZAK DESIGNS, INC.          China   Washington  Airway Heights
# ...

# %%
import pandas as pd
import numpy as np

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %% [markdown]
# # Concatenating the files

# %%
df_final=pd.concat([df,df1,df2,df3])
df_final
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0         10121                   Horses, live, pure-bred breeding
# 1         10121                   Horses, live, pure-bred breeding
# 2         10121                   Horses, live, pure-bred breeding
# 3         10121                   Horses, live, pure-bred breeding
# 4         10121                   Horses, live, pure-bred breeding
# ...         ...                                                ...
# 759802   961380                                      Lighters, nes
# 759803   961511  Combs, hair-slides and the like of hard rubber...
# 759804   961519  Combs, hair-slides and the like, other than ha...
# 759805   961590  Hairpins, curling pins, hair-curlers and the l...
# 759806   961700  Vacuum flasks/vacuum vessels complete with cas...
#
#                              COMPANY-ENTREPRISE        COUNTRY PROVINCE_ENG  \
# 0                    HATFIELD FARM INCORPORATED  United States  Nova Scotia
# ...

# %%
df_final.to_csv(r'C:\Users\namit\OneDrive\Desktop\Sem2\finaldata.csv')
