# %%
import pandas as pd
path = ('2012_2014.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['Sheet1']

# %%
df1 = xl.parse('Sheet1')
df1
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        853710  Boards, panels, including numerical control pa...
# 1        853720  Boards, panels, including numerical control pa...
# 2        853890  Parts for use with the apparatus of Nos 85.35,...
# 3        853910                             Sealed beam lamp units
# 4        853921                   Filament lamps, tungsten halogen
# ...         ...                                                ...
# 672813   961800  Tailors' dummies/lay figures; automata and oth...
# 672814   961800  Tailors' dummies/lay figures; automata and oth...
# 672815   701090  Carboys,bottles,flasks,jars,pots,etc,nes,of gl...
# 672816   420221  Handbags, with outer surface of leather or of ...
# 672817   711319  Articles of jewellery & pts thereof,of o prec ...
#
#                                 COMPANY-ENTREPRISE  \
# 0                          GENERAL ELECTRIC CANADA
# 1                          GENERAL ELECTRIC CANADA
# ...

# %%
import pandas as pd
df = pd.read_excel('2012_2014.xlsx', 'Sheet1')
df
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        853710  Boards, panels, including numerical control pa...
# 1        853720  Boards, panels, including numerical control pa...
# 2        853890  Parts for use with the apparatus of Nos 85.35,...
# 3        853910                             Sealed beam lamp units
# 4        853921                   Filament lamps, tungsten halogen
# ...         ...                                                ...
# 672813   961800  Tailors' dummies/lay figures; automata and oth...
# 672814   961800  Tailors' dummies/lay figures; automata and oth...
# 672815   701090  Carboys,bottles,flasks,jars,pots,etc,nes,of gl...
# 672816   420221  Handbags, with outer surface of leather or of ...
# 672817   711319  Articles of jewellery & pts thereof,of o prec ...
#
#                                 COMPANY-ENTREPRISE  \
# 0                          GENERAL ELECTRIC CANADA
# 1                          GENERAL ELECTRIC CANADA
# ...

# %%
path = ('2015-2016.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['Sheet1']

# %%
df1 = xl.parse('Sheet1')
df1
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        482190             Paper labels of all kinds, not printed
# 1         70190                    Potatoes, fresh or chilled, nes
# 2         70200                         Tomatoes, fresh or chilled
# 3         70200                         Tomatoes, fresh or chilled
# 4         70200                         Tomatoes, fresh or chilled
# ...         ...                                                ...
# 434786   940360                             Furniture, wooden, nes
# 434787   940360                             Furniture, wooden, nes
# 434788   630293       Toilet and kitchen linen, of man-made fibres
# 434789   630391  Curtains,incl drapes,int blinds & curtain/bed ...
# 434790   630391  Curtains,incl drapes,int blinds & curtain/bed ...
#
#                                        COMPANY-ENTREPRISE        COUNTRY  \
# 0                            PROVINCIAL FRUIT CO. LIMITED  United States
# ...

# %%
df2 = pd.read_excel('2017-2018.xlsx', 'Sheet1')
df2
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0         80711                                 Watermelons, fresh
# 1         80711                                 Watermelons, fresh
# 2         80711                                 Watermelons, fresh
# 3         80711                                 Watermelons, fresh
# 4         80719                                 Melons, nes, fresh
# ...         ...                                                ...
# 730245   961511  Combs, hair-slides and the like of hard rubber...
# 730246   961519  Combs, hair-slides and the like, other than ha...
# 730247   961590  Hairpins, curling pins, hair-curlers and the l...
# 730248   961800  Tailors' dummies/lay figures; automata and oth...
# 730249   962000     Monopods, bipods, tripods and similar articles
#
#                            COMPANY-ENTREPRISE        COUNTRY PROVINCE_ENG  \
# 0       CANADIAN FRUIT & PRODUCE COMPANY INC.  United States      Ontario
# ...

# %%
df3 = pd.read_excel('2019-2020.xlsx', 'Sheet1')
df3
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0         90210  Green tea, not fermented, in packages not exce...
# 1         81340      Fruits, dried, nes, o/t of Nos 08.01 to 08.06
# 2         81350  Mixtures, of edible nuts or dried fruits of th...
# 3         90121                 Coffee, roasted, not decaffeinated
# 4         90122                     Coffee, roasted, decaffeinated
# ...         ...                                                ...
# 759862   961380                                      Lighters, nes
# 759863   961511  Combs, hair-slides and the like of hard rubber...
# 759864   961519  Combs, hair-slides and the like, other than ha...
# 759865   961590  Hairpins, curling pins, hair-curlers and the l...
# 759866   961700  Vacuum flasks/vacuum vessels complete with cas...
#
#                    COMPANY-ENTREPRISE        COUNTRY PROVINCE_ENG CITY-VILLE  \
# 0       STARBUCKS COFFEE CANADA, INC.  United States      Ontario    Toronto
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35768\2113916660.py in <module>
# ----> 1 df_final=pd.merge(df,df1,df2,df3)
#       2 df_final
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     680             warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
#     681
# --> 682         self._validate_specification()
#     683
# ...

# %%
import pandas as pd
import numpy as np

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
df_final=pd.concat([df1,df2,df3,df])
df_final
# Out:
#         HS6-SH6                                    DESCRIPTION_ENG  \
# 0        482190             Paper labels of all kinds, not printed
# 1         70190                    Potatoes, fresh or chilled, nes
# 2         70200                         Tomatoes, fresh or chilled
# 3         70200                         Tomatoes, fresh or chilled
# 4         70200                         Tomatoes, fresh or chilled
# ...         ...                                                ...
# 672813   961800  Tailors' dummies/lay figures; automata and oth...
# 672814   961800  Tailors' dummies/lay figures; automata and oth...
# 672815   701090  Carboys,bottles,flasks,jars,pots,etc,nes,of gl...
# 672816   420221  Handbags, with outer surface of leather or of ...
# 672817   711319  Articles of jewellery & pts thereof,of o prec ...
#
#                                 COMPANY-ENTREPRISE  \
# 0                     PROVINCIAL FRUIT CO. LIMITED
# 1                            TOMATO KING 2010 INC.
# ...

# %%
df_final.to_csv(r'C:\Users\namit\OneDrive\Desktop\Sem2\final_data.csv')
